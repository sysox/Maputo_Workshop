# %% [markdown]
# # PV181 Seminar 02- RNG (python)
#
# This notebook contains python code for several tasks treated in this seminar.

# %% [markdown]
# # PRNG

# %% [markdown]
# # Task 1: determinism of PRNG
#
# We will work with PRNG implemented in [random](https://docs.python.org/3/library/random.html) package. See first 4 methods (`seed, setstate, getstate, randbytes`) in the documentation.
#  1. Import **random** package.
#  2. Generate (and print) 10 random bytes.
#  3. Print out bytes in hexadecimal form (use `.hex()` method of bytes). Execute cell 2x. </br> PRNG produced different results since  generation is not deterministic as it is seeded by time.
#  4. Use fixed `seed` and verify that generation is deterministic (generated bytes are always the same).
#  5. Verify that seed determines internal state of the generator. What is the internal state for `seed = 1`?
#  6. Use `seed = 1` and generate 10 bytes. Use the internal state from previous step 5. and generate the same 10 bytes - you should see same bytes.
#  7. **Attack**: The generator produced 16 bytes that will be used as AES key. The first half of is `73a9bef499bbf4dca4f2`. Find the rest of the key. </br> **Hint**: user used small seed.

# %%
import random 
rnd_bytes = random.randbytes(10)
print(rnd_bytes)
print(rnd_bytes.hex())

random.seed(2)
state = random.getstate()
print(random.randbytes(10).hex())

# # print(state)
# random.setstate(state)
# print(random.randbytes(10).hex())
# Out:
# b'\xc4\x8e\x9fv\x11\x85S\x08\xe8\xd7'
# c48e9f7611855308e8d7
# 73a9bef499bbf4dca4f2

# %% [markdown]
# # LCG
# Standard PRNG functions are very fast but also very weak.
#  * In python, PRNG [implemented](https://svn.python.org/projects/python/branches/release32-maint/Lib/random.py) in random module is [Mersenne Twister](https://en.wikipedia.org/wiki/Mersenne_Twister) with state formed by 625 32-bit integers. See size of the state in Task 1 above.
#  * In other languages (C, Java, Rust) LCG is typically used. Internal state of LCG is **single** value (state) updated iterativelly as $$state = (state*a+c) \pmod m.$$ Overview of constants `a,c,m` used by the LCG for several languages can be found [here](https://en.wikipedia.org/wiki/Linear_congruential_generator).
#  </br>
#  <span style="color:red">In LCG, state (new or old) is typically returned as generated random value!!</span>

# %% [markdown]
# # Task 2: common rand PRNG
# Following code was taken from [ANSI C standard](http://www.open-std.org/jtc1/sc22/wg14/www/docs/n1256.pdf#page=324) and simplified to other portable implementation (according to implementation of [rand()](https://code.woboq.org/userspace/glibc/stdlib/random_r.c.html#__random_r)) of seeding function `srand` and function for generation `rand()`.
#
# ```
# static unsigned long int next = 1;
#
# void srand(unsigned int seed)
# {
#     next = seed;
# }
#
# int rand(void)
# {
#     return next = (next * 1103515245 + 12345) & 0x7fffffff;
# }
# ```
#  1. Implement pythonic version of ANSI C PRNG - implement it as `class PRNG` below. </br> Use constants $a=1103515245, c=12345, m=2^{31}$ from [LCG wikipedia](https://en.wikipedia.org/wiki/Linear_congruential_generator).
#  2. Generate 10 values $12345, 1406932606, ...$ with LCG seeded by 0.
#  3. Generate 10 values but use different seed so the sequence will start with $1406932606, ...$.

# %%
class PRNG:
    def __init__(self):
        self.srand(1)

    def srand(self, seed):
        self.state = seed

    def rand(self):
        self.state = (self.state * 1103515245 + 12345) % 2**31
        return self.state

ansi_rand = PRNG()
ansi_rand.srand(0)
rnd_values = [ansi_rand.rand() for i in range (4)]
print(rnd_values)
# Out:
# [12345, 1406932606, 654583775, 1449466924]

# %% [markdown]
#  4. Every PRNG generates values in cycle i.e. generated sequence is periodic. Find the seed of the generator for which the generated sequence would be `[??, ??, 12345, 1406932606]`. Find previous two values (replaced by ??). </br>
#  **Hint**:
#  To revert this PRNG you can use constants $a^{-1}$ and $(c*a^{-1})$ instead of constants $a$ and $c$.  </br>
#  Compute $a^{-1}$ and $(c*a^{-1})$ for ANSI C and generate (`[1406932606, 12345, ??, ??, seed]`).</br>
#  In order to find backward LCG  it suffices to invert the update function: $$new\_state = old\_state*a+c \pmod m.$$
#  The inverse function can be computed as
#     $$
#     \begin{align}
#      old\_state &= (new\_state - c)/a \pmod m \\
#                 &= new\_state*(a^{-1}) - (c*a^{-1}) \pmod m \\
#     \end{align}
#     $$
#   where $a^{-1} \pmod m$ can be computed using `*pow(a,-1,m)`. </br>
#
#   5. Use LCG.py script and generate sequence of 10 numbers for java_util_random with `seed=1`. Folowing cmd will generate the sequence for you. Verify (google) that sequence is correct. </br>
#   `python3 LCG.py -m 2**48 -a 25214903917 -c 11 -s 0 -l 16 -u 47 -n 10`

# %% [markdown]
# # Task 3: small state attack
#  1. Use rng and generate random bytes which will be used below as AES key (16B).

# %%
from cryptography.hazmat.primitives import hashes

def SHA1(message: bytes):
    digest = hashes.Hash(hashes.SHA1())
    digest.update(message)
    return digest.finalize() 

def SHA256(message: bytes):
    digest = hashes.Hash(hashes.SHA256())
    digest.update(message)
    return digest.finalize() 

class PRNG:
    def __init__(self):
        self.srand(b'0x00')

    def srand(self, seed):
        if isinstance(seed, int):
            self.state = seed.to_bytes(1, 'little')
        else:
            self.state = seed
        self.state = self.state[:1]

    def rand_bytes(self, num_bytes=10):
        rnd = SHA1(self.state)[:num_bytes]
        self.state = SHA256(self.state)[:1]
        return bytes(rnd)

rng = PRNG()
seed = os.urandom(0)  # use os.urandom to generate 1 random byte as a seed
rng.srand(seed) # use seed to initalize the PRNG
K = rng.rand_bytes(16) # generate the K

# %% [markdown]
#  2. Use `encrypt_ECB` and `encrypt_ECB` to encrypt and decrypt arbitrary short(16B) message.

# %%
from cryptography.hazmat.primitives.ciphers import Cipher, algorithms, modes
import os

def encrypt_ECB(key, msg):
    cipher = Cipher(algorithms.AES(key), modes.ECB())
    enc = cipher.encryptor()
    ct = enc.update(msg) + enc.finalize()
    return ct 

def decrypt_ECB(key, ct):
    cipher = Cipher(algorithms.AES(key),  modes.ECB())
    dec = cipher.decryptor()
    pt = dec.update(ct) + dec.finalize()
    return pt

rng.srand(os.urandom(1))
K = rng.rand_bytes(16)
ct = encrypt_ECB(K, b'arbitrarymessage')

print(ct)
# Out:
# b'\xdf\xd1v&2\x9f\xce\x9b|\x7f\xca$[(\r\xf2'

# %% [markdown]
#  3. **Attack**: Find all possible 16 byte blocks `rng` can produce and decrypt the ciphertext `ct`. The internal state is only 1 byte long and can be set to arbitrary value using ``.srand()`` method.

# %%
for seed in range(256):
    rng.srand(seed)
    key = rng.rand_bytes(16)
    pt = decrypt_ECB(key, ct)
    print(pt, key)
# Out:
# b'B\xd6\xf4\xd1\xfe}\x8bc\xbd"\x88T\x8f\xd6\x0f\x1c' b'[\xa9<\x9d\xb0\xcf\xf9?R\xb5!\xd7B\x0eC\xf6'
# b'\x87\xb9\x9aQw\xe5\xd4\xae\x10M\xee\xcb\xea\xcd\xfc\x1e' b'\xbf\x8bE0\xd8\xd2F\xddt\xacS\xa14q\xbb\xa1'
# b'\x0b1s\x13\xa5\xb9\xfc\xc9\xe8\xb5qlhM\xa0\xcb' b'\xc4\xea!\xbb6[\xbe\xea\xf5\xf2\xc6T\x88>V\xd1'
# b'\x05-\xc2O\x97\xf4\xf1wX\xa2\x03R\x04\xa1+\xb5' b'\x98B\x92j\xf7\xca\n\x8c\xca\x12`O\x94T\x14\xf0'
# b"\xe8\x9d\xd4n\xfa>@(S`\x1c\xbc\x81P\x8f'" b'\xa4,l\xf1\xde:\xbf\xde\xa9\xb9_4h|\xbb\xe9'
# b'\xe5\xf1b\xb5.\x8d\xc7\x01Z\xdf_\x86Z)\xcc\x81' b'\x8d\xc0\x05\x98A}N\xb7\x88\xa7z\xc6\xcc\xef<\xb4'
# b'\xf8\x02\xebt\x10\x14V\x95\xa3\x887\xe2\xd7\xebd\x03' b'-\x014\xed;\x9d\xe12\xc7 \xfei{S+L'
# b'\x94\xf4\xc2PF\xa2\x99\xe7T\xdd\x8c\xdb\xc6u\xbe\x9b' b']\x1b\xe7\xe9\xdd\xa1\xee\x88\x96\xbe[~4\xa8^\xe1'
# b'\x08\x03:\x8d\xe0D*Xw\x8b4<~\xb6~\xb5' b'\x8d\x88?\x15w\xca\x8c3K|mu\xcc\xb7\x12\t'
# b"\x0b\x18\x8bm\xeep'SS\xe5\x80A\x051V\xaa" b'\xac\x921\xda@\x82C\n\xfe\x8fM@\x12x\x14\xc6'
# b':K\xac\xf3\x0c\x07Pu\xfe6\xb0\xa5\x95\xd2\x17\x85' b'\xad\xc8;\x19\xe7\x93I\x1b\x1cn\xa0\xfd\x8bF\xcd\x9f'
# b'\x9c\xd00\xa6\xa2\x1e\x9fI\x13d\xa6#C\r\x17\xb4' b'\x06}P\x96\xf2\x19\xc6KS\xbb\x1c}^7T('
# b'\x1d\xe7\x15L\x07\x0c\xf9h\xa1-\xd0\x8al`p\xb1' b'\x1e2\xe3\xc3`P\x1a\x0e\xde7\x8b\xc4Z$B\r'
# b'v=\xf3(\x0em3j\xa3\\\xcci\x13\xc1I\t' b'\x11\xf4\xdek\x8bE\xcf\x80Q\xb1\xd1\x7f\xa4\xcd\xe9\xad'
# b'\x89\xaf\x00\xe2\x82\x82\x92\nJ^\x86X\xe2\x93#[' b'2\x03U\xce\xd6\x94\xaai\x92Ok\xb8.{t\xf4'
# b'\x97q\xd8\x1e\xd2r\x7f\x93\xda>\n\x9b\xdf+\xbbf' b'\xc7%]\xc4\x8bB\xd4Ol\x06v\xd6\x00\x90Q\xb7'
# b'E\x98\x00\x95\xca\xa0\xdfZ4\xf2\xe8?\xf2Y\x0cG' b'n\x14\xa4\x07\xfa\xae\x93\x99W\xb8\x0ed\x1a\x83g5'
# b'\xff6n\x80\xb5\x15\xc2.[9Oh\xd3\xefd\xcf' b'\xa8\xab\xd0\x12\xebY\xb8b\xbf\x9b\xc1\xeaD=/5'
# b'\xcf\xb6\xdf\x82(\xe3Z\xd8\xc9\xc7[x\x8b\x9e\x15.' b'\xc4\xf8zb\x90\xae\xe1\xac\xfc\x1f&\x089t\xce\x94'
# b'\xbfDWu_Yuij\x8e\x990\x84\xd2\xd7!' b'Z\x8c\xa8L}M\x9b\x05_\x05\xc5[\x1fp\x7f"'
# b'O\xf2\xdc\x8d\xe7J\x00j,y\xfa\xba\xa8\r\x13R' b'<\xe0\xa1\xaf\x90\xb6\xe7\xa3\xdd\x8dE\xe4\x10\x88KX'
# b'\xa2\x85s\x9f\xd6\xe6\xf0\x01^\xb0!\xf4A\xb6\xcbl' b'wb\xea\xbf\x93\x87\xfe\x8e\xc5\xd6H\xcd;\x1d\x9e\xb6'
# b'\x18\x1b-\xf8\xc8q\xe5\xeeLF\xc4>\\\xf9LI' b'\xa9\xd3\xc9\xcdT\xb1\xa3\x92\xb2\x1e\xa1I\x04\xd9\xa3\x18'
# b'\xd0\xb3\xcf[\xdb\xab\xdcN\xec\x05\xa0GD\xb9#\xa5' b'\tM\x98\xb3\x99\xbfJ\xce{\x88\x99\xabp\x81\xe8g'
# b'\x88\xec\xc6\xcb\xd3g\x14\x8c\x10%OnP\xed#\x00' b'\xc2\x14;\x1a\r\xb1yW\xbe\xc1\xb4\x1b\xb2\xe5\xf7Z'
# b'\xa54Q\xeb\xe0\x8bZ\xce\xd9\xbe\xe3\xf9\t\xbe\x03\x8d' b'\xe9\xc5\xd7\xdb\x93\xa1\xc1}E\xc5\x82\r\xafE\x82$'
# b'\xcd%\xdd/\xebO\xd5\x82\xef\xc5\xf6\xa3\xc6~>D' b'\xeb\xdc"\x88\xa1B\x98\xf5\xf7\xad\xf0\x8e\x06\x9b9\xfc'
# b'\x07n\xea*c\x17)v\x81A\xa3\xa9{5\x89>' b"'\xf5|\xb3Y\xa8\xf8j\xcfJ\xf8\x11\xc4zc\x80"
# b"j'D\x81\x98\xb4'\xbbw\xc4+\xfe`\xfb\xcdp" b'\xb80\xc4m$\x06\x80i\xf0\xa46\x87\x82o5['
# b'G/\x8d\xad\xb9\x8b\x03\x03\xd8\xbb\x04\xba\x91t\x1f\x1a' b'Y\x83\xad\x8fk\xfe\xa1\xde\xday@\x9c\x84OQ7'
# b'\xd0O~!H\xbaHL\x8f\x93a\xab\x93\xdd\xd1\xf3' b'\x7f\xd8\x8c2\x9bc\xb5ur\xa0\x03,\xf1N>\x9e'
# b'\xc9\x02\x8a)\xfe\xae\x95\x1d5\x9a\x85*\x8d\x94V7' b'\x95>\xfe\x8fS\x1aZ\x87\xf6\xd2\xd5\xa6[x\xb0^'
# b'\x8dE\xde\x1ad\xbd>=\xa3k1wt\x9d_\x11' b'\xb8X\xcb(&\x17\xfb\tV\xd9`!\\\x8e\x84\xd1'
# b'\xb7J\xcd1\xc4\xdc\xbd\xcf&lCM\x98\xf5\xd5\xda' b'\n\xb81\x8a\xca\xf6\xe6x\xdd\x02\xe2\xb5\xc3C\xedA'
# b'\x93\x9e\xc6\xad\xe3\xe4-\xc0\x015\x11B\x17R\xa6j' b'*\xceb\xc1\xbe\xfa\x19\xe3\xea7\xddR\xbe\x9fmP'
# b'\xd3\xd1e\x91\x92\x80\x11\xab\x1eU\xc9l$\x8a\x0f\xe2' b'\xd0\x8f\x88\xdft_\xa7\x95\x0b\x10NJpz1\xcf'
# b'I\xb6\xd2)\x12\xc0\xe8\xc7\x1a\x19e\x84\xf0\xd7\xb5\x11' b'<\xdf)6\xda/\xc5V\xbf\xa53\xab\x1e\xb5\x9c\xe7'
# b'w\x92\x10>x{C^\x05;#\x03\xdd\xe4\xec\\' b'CE\xcb\x1f\xa2x\x85\xa8\xfb\xfe|\x0c\x83\nY,'
# b'\xc4M\x02\x93U@j\x95\x14P:\xa4\xc3B^\xab' b'|M3x]\xaa\\#p \x1f\xfa#kBz'
# b'\x88\x91\xf4q\x15\xb1\xb4$i\xf2\x83\x82\xf5\x8e\xbbn' b'\xbbX\x9d\x06!\xe5G/G\x0f\xa3BZ#Lt'
# b'2\xac(\x05\x90\xf3X\xe6\x06\x1b\x8a\xf9\xaf \xfa\xcf' b'(\xed:y}\xa3\xc4\x8c0\x9aN\xf7\x92\x14\x7f<'
# b'uH\x0f\xc8\xb9\x84hGF0\xd9d\x8ac\x1a\x0b' b"\xe7\x06O\x0b\x80\xf6\x1d\xbce\x91S\x11\x03-'\xba"
# b'\xbaVGS\x93\x97>\n\x04<*"\xc1\xb2}e' b'\xdfX$\x8cAO4,\x81\xe0V\xb4\x0b\xee\x12\xd1'
# b':s\xd0/I\xc7\xeb\x1f\xcb\xd5\x1b\xc2U\xdd\xf7\xa4' b'\xa9y\xef\x10\xccoj6\xdfk\x8a23\x07\xee;'
# b'\xe0\xa5BM<\x92s\xd5f\xa4\xd5\x9c\x07\x8a\x80\x8a' b'\\\x10\xb5\xb2\xcdg:\x06\x16\xd5)\xaaR4\xb1.'
# b'\xfd\xce\x91\xd8\xb3\x0e[Z\x85\xc1\xa7\xdcX\xb6\xd7\x94' b';\xc1\\\x8a\xae>A$\xdd@\x905\xf3.\xa2\xfd'
# b"\xe4\x95\xcc_A\xd2'\x95\xdezQ\xc8z\x88\x95<" b':R\xcex\tP\xd4\xd9iy*%Y\xcdQ\x9d'
# b'\x8e\x05\xf5\xdff"\x12-\x92\x11\xdd\xce\x93\x0eG\xf8' b'B\t\x9bJ\xf0!\xe5?\xd8\xfdN\x05l%h\xd7'
# b'\x04,\xf2k\x18\x8a\xfbo\x03\xa5\xf5\xe9\xd8\x08,\xc4' b'\xb6X\x9f\xc6\xab\r\xc8,\xf1 \x99\xd1\xc2\xd4\n\xb9'
# b'6\xb0\xa7\x19\x11\x816\xd4\x11\x8fhD\xbdo\xe3[' b'5j\x19+y\x13\xb0LTWM\x18\xc2\x8dF\xe6'
# b'\x14\x99Rx\xe5\xc9\xe8pb\xa4\xbf\x8a\x9a\x8f\x8b\xa0' b'\xdaK\x927\xba\xcc\xcd\xf1\x9c\x07`\xca\xb7\xae\xc4\xa8'
# b'\xc5j1{oQ E\xa2\xbfi\xcc_!\xbc\xcd' b'w\xdeh\xda\xec\xd8#\xba\xbb\xb5\x8e\xdb\x1c\x8e\x14\xd7'
# b'\x03\x1a\xceH\x9e\x9e\xfe\x8e\x0c\xa5\x89HJ\x9c/\x96' b'\x1bdS\x89$s\xa4g\xd0sr\xd4^\xb0Z\xbc'
# b'\xc8\xbf\n\xa6\xc9Gpj\x14F\x95\xb9\xdb\xcb9\xd4' b'\xac4x\xd6\x9a<\x81\xfab\xe6\x0f\\6\x96\x16Z'
# b'\xbe\xd6\x1a\xc9d\x92/\xc1::\xfe5%G\xe0\x88' b"\xc1\xdf\xd9n\xea\x8c\xc2\xb6'\x85'[\xca8\xac&"
# b'F>\x18F\xc7\xe4MV\xe8\x98v\xdc\xb4\xd1Q\x92' b"\x90+\xa3\xcd\xa1\x888\x01YKn\x1bE'\x90\xcc"
# b'\xccF+\xa8\xec\x944\x8f\xc0s\xf7<\xee\x9e\xbb_' b'\xfe]\xbb\xce\xa5\xce~)\x88\xb8\xc6\x9b\xcf\xdf\xde\x89'
# b'pN\x0e\x84\xb0\x81\xe0c\xc3\xd4\x8e\xfe[l\xfd\x8a' b'\n\xde|,\xf9\x7fu\xd0\t\x97_Mr\r\x1f\xa6'
# b'\xfb\xac\xb5u\xbf2\x05\xf2\x1a\xb7\xb60\x9a\xc2k3' b'\x05\xa7\x9f\x06\xcf?g\xf7&\xda\xe6\x8d\x18\xa2)\x0f'
# b'.T\xe3\xb3\xa6\x18\xbc\x87\\\xcaZV7\xc2>6' b'-\x14\xab\x97\xcc=\xc2\x94\xc5\x1c\rh\x14\xf4\xeaE'
# b'=\xdc\xab\\SK\x06\xf1\x86c\xa5\x1c\x14\x9em_' b'\xc4\xdd<\x8c\xdd\x8d|\x95`=\xd6\x7f\x1c\xd8s\xd5'
# b'<H\xf8I2N\xe4\xda\xddm\x04p3<Gu' b'!`g\x82\xc6^D\xca\xc7\xaf\xbb\x90\x97}\x8bo'
# b'\xff:\x10u\x84\x00\xf1\xd4B\x84\xb0~%({p' b'\t\x13\x85\xbe\x99\xb4_E\x9a#\x15\x82\xd5\x83\xec\x9f'
# b'\x9e\xce\xc6}\n\xde\xf7s\xef!sY2\xd3a\x86' b'[\xaba\xebS\x17dI\xe2\\,\x82\xf1r\xb8,'
# b'U\xf5\xf7\x9e\xbfq%yd\x8fg\xa2Vz-b' b'\x9ax!\x146\xf6\xd4%\xec8\xf5\xc4\xe0"p\x80'
# b'\xa1C\x12\xbb\x81Xw{k\xabJ\xe1\x80\xaaN)' b'm\xcdL\xe2=\x88\xe2\xee\x95h\xbaTl\x00|c'
# b'\x19\xdb\xfd\xb2`\xd0\x81\xbc\xdd\xfa;\x19\x9e\xd0\xb3\n' b'\xaeO(\x1d\xf5\xa5\xd0\xff<\xadcq\xf7m\\)'
# b'\xc6\xab\xae\x88L)\xf4\xff\xf2\xbe\x16\x8e1\xd8h\x06' b'2\tl.\x0e\xff3\xd8D\xeemgT\x07\xac\xe1'
# b'N\xe2\xc9\r\xb1\xa8\xf1\xc6J\xbf\x18\xae\x9e\xbew[' b'P\xc9\xe8\xd5\xfc\x98r{K\xbc\x93\xcf]d\xa6\x8d'
# b"\xf2r'\xc2xFu\x1a\x7f\xeb\xa0qT\x05\x92\x18" b'\xe0\x18J\xde\xdf\x91;\x07f&dm?R\xc3\xb4'
# b'\x06\xac_\xbdMB9\xfc\x87\xb3\xfc\xfa\x7f\xb8\x95\xb3' b'\xe6\x9f \xe9\xf6\x83\x92\r?\xb42\x9a\xbd\x95\x1e\x87'
# b'\xd3\x08\x9e\xe3\xa1\xe5\xca\xfc\xd8\xb3;\x19\xc6#\x1f/' b'\xa3jg\x18\xf5E$\xd8F\x89O\xb0K[\x88['
# b'I5\xa8#<\xcf\xe33\xc0\xae\xdcmS\xc0\xbe\xd2' b'|\xf1\x84\xf4\xc6z\xd5\x82\x83\xec\xb1\x93Ir\x0b\x0c'
# b"\xfe\xc8\x86P\xe4\xa9R\xf6\xfdj9VA'\xfb\xc9" b'\xcas\xabeV\x8c\xd1%\xc2\xd2z"\xbb\xd9\xe8c'
# b'H1\x02z\xbd\x84\x05\x87-\xef\xbb\x9f\xf3\xd5\xdc\x82' b'Xf\x8evi\xfdVM\x99\xdb]X\x1f\xcd\xb6\xa5'
# b'\x7fl\xb8\x7f\x86p\xfaO.Q\xfea\xd5d"1' b'\xa7\xee8\xbb{\xe4\xfcD\x19\x8c\xb2h]\x96\x01\xdc'
# b'[\x04\x82\xde\xb8>\xef\xf3l\x97\xe69\\8X\x81' b'\xd1`\xe0\x98j\xcaG\x14qJ\x16\xf2\x9e\xc6\x05\xaf'
# b'P\xf8\x1bz\xa2H\x03\xf0m\xb8\xe0i\xe9\x10w`' b"\xc6:\xe6\xddO\xc9\xf9\xdd\xa6ip\xe8'\xd1?|"
# b'\xab\x87\xa1b\xca\xe7\xa8\xa3Xn\x0b\xd4\xa2\xeei\t' b'\xb5\x1a`sM\xa6K\xe0\xe6\x18\xba\xcb\xea(e\xa8'
# b']\xb53ib\xc4\xea\xa7\xd2!\xd9\xf2\xaf\xab!\xac' b'\x08\xa9\x14\xcd\xe0P9iN\xf0\x19M\x9e\xe7\x9f\xf9'
# b'\xe2\xfd\nW\xad\x93\xe2\xf1M\xf0\xed@W\xd2n\x8e' b'Q\x19\x93\xd3\xc9\x97\x19\xe3\x8agy\x070\x19\xda\xcd'
# b'\x0c\xc7\xa4\xf7\xfb\xc8\xfb^\x99O\xae\x0b\xben!\x08' b'\xc3\x15n\x00\xd3\xc2X\x8cc\x9e\r<\xf6\x82\x12X'
# b'\xb9\x9d\x8f:\x8e\xf3)\x98\x86\x02\xabl;\x80\x82\xbb' b'\x06WeV\xd1\xad\x80/$|\xad\x11\xaet\x8b\xe4'
# b"\x1a}\xbc\x05j\xc2gGEn'\xc7\xe1\xe6\xc3\xf0" b'\x02\xaab\x9c\x8b\x16\xcd\x17\xa4O:\x0e\xfe\xc2\xfe\xed'
# b'\x19WD\xd8\xf3\xf0u\xc8\xc07\xb7\x12\xeb2\xa4\xd9' b'\xc2\xc5=f\x94\x82\x14%\x8a&\xca\x9c\xa8E\xd7\xac'
# b'\x97\x8es\x14\xab1\x9d\x8bn\x1a\xd1\xa8S4\xcf,' b'\xb2\xc7\xc0\xca\xa1\n\x0c\xca^\xa7\xd6\x9eT\x01\x8a\xe0'
# b'\\]\xad\ni\x84\xad\x9e\xe5\xbcwM\x92Z\xab\xa8' b'\xc9\xeeV\x81\xd3\xc5\x9fuA\xc2z8\xb6~\xdfF'
# b'\x1e\x98Q\xea>\x80\xed|n1\xf3\xec\xff\xe7\xbeh' b'\xe2A\\\xb7\xf6=\xf0\xc9\xde#6#&\xad<7'
# b'E\x92\x83.\x82.Q\xaa\xf4%o\xf9\xf8\xf9\xd3\xa4' b"\xc02\xad\xc1\xffb\x9c\x9bf\xf2'I\xadf~k"
# b'2\xdf\x1b\x1a!6-\n\xf2>\x13\x99\x15\xd1!6' b'#\xebM?AU9Zt\xe9\xd54\xf9\x7f\xf4\xc1'
# b'\x9eT\xae\xd7\x1d\xd6^8\x08^\xaa\xf0\xabo\x1b\x15' b'\x90\x9f\x99\xa7y\xad\xb6jv\xfcS\xabV\xc7\xdd\x1c'
# b'\x9a\x06F\r\x1a0\xb6\xe5\xeaI\xcc\x1f[\x17\xb6\xe7' b'\x1e\\/6\x7f\x02\xe4z\x8c\x16\x0c\xda\x1c\xd9\xd9\x1d'
# b'\r0z\xca\x90*\xcc\x1b\xbb\xfb\x1a\x80\x85\xa2\xfe\xb0' b'\x08SO3\xc2\x01\xa4P\x17\xb5\x02\xe9\n\x80\x0f\x1b'
# b'R\xd0\x1b\x0fa\x86\xde\xca\x85\xa0\xa2\x7f\x8e\xc8\x05z' b'O\xf4G\xb8\xefB\xcaQ\xfao\xb2\x87\xbe\xd8\xd4\x0f'
# b'\x1f0\x8d\x85F\xb1\xa987\xecB\x16\xed\xd0=\x81' b'^o\x80\xa3J\x97\x98\xca\xfcj]\xb9l\xc5{\xa4'
# b'\xe7\xb9&\xde}\xeeQ{\xfa\x19\x11\x86K!!\xe5' b'S\xa0\xac\xfa\xd5\x93y\xb3\xe0P3\x8b\xf9\xf2<\xfc'
# b'|\n\xfe\x19\x02a\xb6\xb2\x05\xb3~\xc0"\xdddL' b'~\x15\xbb\\\x01\xe7\xddVI\x9e7\xc64\xcfy\x1d'
# b'\x8am\xcdU4\xfe\x19%\x04\xdb\xbd~\xb5\xf3\x1b\xc7' b'\x86\xf7\xe47\xfa\xa5\xa7\xfc\xe1]\x1d\xdc\xb9\xea\xea\xea'
# b':9e\xf0\x82\x19\xe7_\xe5\xde\xd7X=7\x11\xbd' b'\xe9\xd7\x1f^\xe7\xc9-m\xc9\xe9/\xfd\xad\x17\xb8\xbd'
# b'\x063\xb9\xf7\xa6|\xd1[Qv\xf3\xaf*k\xcfX' b'\x84\xa5\x16\x84\x1b\xa7z[FH\xde,\xd0\xdf\xcb0'
# b';I(\x8f\xda\x12\x80i\xa49\xb1\x83l\xb9{\x19' b'<686\xcfN\x16ffi\xa2]\xa2\x80\xa1\x86'
# b'\xf7\xc89\x91\x1e&\x1b\xc0\xf1n\x14hv\x05\x90\\' b'X\xe6\xb3\xa4\x14\xa1\xe0\x90\xdf\xc6\x02\x9a\xdd\x0f5U'
# b'\x1b]W\xfe\x90\xb9[+\xa4\xea^\n\xdc\x87\xc3c' b'J\n\x19!\x8e\x08*4:\x1b\x17\xe534\t\xaf'
# b'w\xc7P\x1a\x12W\xa8\xa0a\n\xb2\xcd%\xce\xd1\x8f' b'T\xfd\x17\x11 \x9f\xb1\xc0x\x10\x927A2\xc6n'
# b'B\x8d\xe7\xff-C\xbeH\xfc\x18L\x89\xbdZ\x91\xec' b"'\xd5H.\xeb\xd0u\xdeD8\x97t\xfc\xe2\x8ci"
# b'\x0e\x8e\x83\x80\xbf\x9e\x07\x87\xe3k\xb31\xae\xdc\x82\x03' b'\x04-\xc4Q/\xa3\xd3\x91\xc5\x17\x0c\xf3\xaaa\xe6\xa6'
# b'l\x9b\xbcP\x013\xc2\x0e\xd4\xf8\x9d\xc6\xd4\xb3\x13\xbd' b'\\-\xd9D\xdd\xe9\xe0\x88\x81\xbe\xf0\x89O\xe7\xb2*'
# b'\xda|q\x1ag\x15\x83as2?+\xb3\xb0\xd7\x8f' b'\x13\xfb\xd7\x9c=9\x0e]e\x85\xa2\x1e\x11\xff^\xc1'
# b'1B\x87\xa2\xf0\x8b/\xb1S\xfb\xb1Re_(\xe0' b'\x07\xc3B\xbenV\x0e\x7fC\x84..!\xb7t\xe6'
# b'\r\x179\x18\xd2#i*j\xb2\xe80\x93\xa7r\xf5' b'k\r1\xc0\xd5c"0$\xdaEi\x15\x84d:'
# b':!. \x8bz\xd8\xbd\xdd\xbb\x01\xe1\xf5\x99\xa0}' b'\xd1\x85L\xae\x89\x1e\xc7\xb2\x91a\xcc\xafy\xa2K\x00'
# b'\x04u/\x84\xeb\x15\xd8\xc2(\xe0\x06\x89#\xbfU@' b'z\x81\xaf>Y\x1a\xc7\x13\xf8\x1e\xa1\xef\xe9=\xcf6'
# b'mp\xcd\x978\xa4V\xe6Y\x08\x0c%\xf3\x1cr\x04' b'Qk\x97\x83\xfc\xa5\x17\xee\xcb\xd1\xd0d\xda-\x16S'
# b"!\x13\xdbL\xa7j\x97\x93'\x1b\x14\xd6\x1b\x13\x90&" b'"\xea\x1cd\x9c\x82\x94j\xa6\xe4y\xe1\xff\xd3!\xe4'
# b'A\xed\x97\x95\x8a\xfcr\t\xa1\xc0]\x9fs\xd4b=' b'M\xc7\xc9\xecCN\xd0e\x02vq6x\x97c\xec'
# b'\xf7\xf31\xdeQ\x04\xa3*\x97;yj\x998\xb68' b'\xa0\xf1I\n \xd0!\x1c\x99{D\xbc5~\x19r'
# b'\xbb\x02\xfd\x8a\xfb\x03\x03c\xf2\x1e\xfc\x8cwrfG' b'\x8e\xfd\x86\xfbx\xa5jQE\xedw9\xdc\xb0\x0cx'
# b'\x8akA\x13\xc2\xee\xae\xdb:l\xeeW=\x88\xf6\x81' b'Q\xe6\x98\x92\xabI\xdf\x85\xc6#\x0c\xccW\xf8\xe1\xd1'
# b'(0\xcex\x076Ku\xd6\x1b\xc0<uB\xdbB' b'z8\xd8\xcb\xd2\r\x992\xba\x94\x8e\xfa\xa3d\xbbb'
# b'\x17\x94:\xb8J4w#1E\x93S}\x10\xdf\x1d' b'\xaf\xf0$\xfeJ\xb0\xfe\xce@\x91\xde\x04LX\xc9\xae'
# b'~R\x19\xb2\xa7\xdf1\xe3:d\xd4\x05\x0c\x98\xe8\x1d' b'\x11\xf6\xad\x8e\xc5*)\x84\xab\xaa\xfd|;Qe\x03'
# b'z\xc96+\x0e[;\x89/\xde\xbf\xc6\xc1wC\xce' b'\x95\xcb\x0b\xfd)w\xc7a)\x8d\x96$\xe4\xb4\xd4\xc7'
# b'\xbb\xba\xf2\xa7\xe9{\xa3\x17ZP\\Y\xfenD\xa3' b'9]\xf8\xf7\xc5\x1f\x00p\x19\xcb0 \x1cI\xe8\x84'
# b'\xc8d%\x054\x97\xd4-=iD\xb3\xc3Om\xf7' b'`\xbaK-\xaaN\xd4\xd0p\xfe\xc0f\x87\xe2I\xe0'
# b'\xa3Zy\xe1\x17n\xc4\x92S\x1b\x89\xf8\xa8u\xa5\xd0' b'>\xb4\x16">\x9ei\xe6\xbb\x8e\xe1\x97\x93\x91\x1a\xd1'
# b'\x10\x9f\xe0(\xa6\x01\\\xeb4\xa2oA\xc71\xf5\xd2' b'\xc2\xb7\xdfb\x01\xfd\xd36#\x99\t\x1f\n)U\r'
# b'.\xa8b\xd7\x99<\xd5\x85\x05\xcejNB\x11\xcaJ' b'\xfb<nM\xe8[\xd9\xea\xe2o\xdcc\xe7_\x10\xa7'
# b'\x96\t{\xab\x96\xf7\xbaF\xa8\x94\xcao\x7fvw\xdb' b'#\x834b\xf5U\x15\xa9\x00\xe0\x16\xdb.\xb9C\xfb'
# b'Wy3s\xea\xfc\xe2\xaf\xfd\xc6v\x0f\xf3\xbe\\\xd9' b'\xc7\x8e\xbd<\x85\xa3\x9aYm\x9f\\\xfd+\x8d$\x0b'
# b'\n!\x98\xf7A\xb6\xf9}{\x15\x7fp\x8cE\xdbs' b'\xa3\xf2\x94#_\xe5B \x05\xae\x9b\xc3\xa0\xd1\xbf\xfe'
# b'\x1e\xe7Qn\xed\x89\x0b\x1d\xd4L\xacXG\xab\x04P' b'\xfa\xa1x\x1e\x14D\xbb\xa5\xb8\xc6w\xbc^*8\xd0'
# b'\xb9\xd1W\xceJ<N\x1f\t\x8e(\\!\xc5\xe9\xc5' b'0\x14\x03\x97\xfe8\xeea\xf0\x1e\xffD\xb5\xcf\xa4\x82'
# b"\x953\xf6'S\x1c\xcf\xd9\xf6\xc0\xe5!\xdbJ\xba=" b'\x99\x9a\n\x8c\xad\x10.\xb5\x19\xcax\x8dn\x0c\xd4\x8e'
# b'oa\xc7\xad>\x91Id\xdeA\xdfw\x8f\xa0`\xae' b'\x87h\xa5>\x1dL\x18)\x070c\x00\xf9\xca\x90\xcf'
# b'/f"\xe0Y\xc1\xe2\xda)\xe1\x92zb\n\x83\x12' b'\xa9\xdeP\x1b\xd9cdf#V\xb2\x9f\xae\xe5f.'
# b'\xfe\x82\x06\x1e\xae`Y\x91\xc5z+\xd2\x1b0\xaf)' b'\xcac-(\xf9\x1c\x1b\x8dc\x8d\xf7\x15%\xfe"\xfd'
# b'_\xe1\x00-\xb1\xea\xc6\x819y\xb4\xa8>;\xaf\xd7' b'.t\xd2N\x88vx\xf0h\x1dL|\x01\x04w\xb8'
# b"0\xfaH\xbbs~'\x99\x03\xda\x06`MK\x16\xf8" b'<y#\xf15\xd3X\xfdhPe\xfd\xe8\xa9\x96\xd4'
# b'\xecW\xf6IV\x06H\x03\x94D\x03\xc8\xd2\x87\x12\xde' b"\xc4H\x8a\xf0\xc1X\xe8\xc2\x83,\xb9'\xcf\xb3\xceS"
# b'c\xcf\x82\xe6\x108\x99T\xf4~\x92\xab\xfeg\xe5\xe7' b'\xda\x91O\x19\x13$\xecY\xde;\xdb\xa9L!\xb9\x01'
# b'\xdd\x96\x19|\\IS\xe0\\S\xfd\xcc\x01\xaem\x92' b'\t\x0c\xbcF\xc3\xa1<\xd0_\xce\xb2\xfeU\xcc\xca\xab'
# b'\xfd\x90s\xe1\xa5\xc8\xab\xb7\xf8V\xe6\x07\xd7]\xd0\xca' b'B\x03L\x89]\x06\xd6\xf9\x14\xde\xac\x94\xca\x1d\x87\xcb'
# b'\xb3\xc6Q\x89\x8f\x9f\xeb\x9aI\xb6\x87\x15A4\xc4\xdc' b'f\xb8\xc2V\xf4\xb4\xf6\xce6\xec\x1a\xbe\xde\xdf\x18&'
# b'n\xe0[\xf0\r0"\xa9\xac\xe2Na\x96E=*' b'd\xb6\x8b\xf5\xb8\x82\xb9\xbd\x0b7&r\x87\x98\x0e\xcf'
# b'\x14\x18k+\xea-j\xb9H\xb2\xf81aX\x16&' b'\xc4Y]\x8ft71\xcb\xc1\xca\x0b\xb3K\xe7\x9a@'
# b'\x8c\xad\x10\xc6.~\x9f\x14\\Ep\xfet\x1e\xc7\x1a' b'\xe9\xf9\x87\xc3\xab&\x8b\xa6\xcf\x1c,\xa0u\xd6\xd2k'
# b'\x12\xdbK\x89\xd72)\x95\xa5\x8a\xea\x887N\x86D' b'\xe6|\xb5\x9b1h\xe1.\xa7\x87\xb8Cr\xab\x07V'
# b'Q;\xabhv\xb0\x99c\xf59n\xf7\x8b\x01\x83\xb0' b'\xbb}\x06[wh33}>\x1a0q\xdeM]'
# b'fD\x994\x7f\xc2F8\xdbPbn\xca3\x00`' b'\x04\xf0)\xfe\xcc\xd2\xc5\xc3\xd3\xef\x872\x9e\xb8V\x06'
# b'\xfeKH\x06;H\xdc-\xf2:\x8f\x8b\x16=\x17G' b'\xbc\x85\xc9\xfa\x1b\x17\xf3\xb8\xe2N\xac42\xff\xf6&'
# b'\xdb\xeaw"h\x99\xfd\x11\x82\x036\x8dk\xe5\x9e\x05' b"\xb8\xf3\xee\xc6\xb5\xfa'\x0f\xb0VD\xde@=\x90w"
# b"\xb1\xb2\xdd\xfb\xfd~(\xda$'\x02+u\xd8\\\\" b'\xfa\x13\x8a\xe3V\xd3\\\x8dw\x08<@j[\xe77'
# b'\xc7\xd1\xd9l\t\xf7\x1c\x06A\xaf\x17BT-\x1bE' b'R\xa7\x19\xf9\xd0\x1ej\x18\x82\xf9{\xc0\x11\xe5,\x80'
# b"f\x15\x10>\xcc\x88\x87\xef9\rL\xa4\xac'\xbe4" b'\xb2[\x0f\xbfF\xce\xf1\xd8\x88\xfe\x90\x04E\xc9\xab\x95'
# b'\xaa\xae\xd2\x01*\xaa\xea\x13\xb8\x11{\xa5\xa4W x' b'\x13\xcb\xa1w\xbc\xfa\xd9\x0e{=\xe7\x06\x16\xb2\xe5K'
# b'@V\x14\x0e\x94\xf3\x19\xa3\xdf\x0e\xe2KE\xa2\xbe\xe2' b'`\xc7\x9eu\xf9\xc2\xea_Z\xaf!\xec*\xd7\xd5\xb1'
# b'\xe7\x19\x1e\xc0oX:A\xb7\xa5q\x06\x14|\xd7\x99' b'\x89\x7f\x93\x99\xae\xbb+ac\xb8\x17[\x8eP\xc5+'
# b'\xd1\xd3\xcb\xce`\xd0\xb5-\x13f\xe5m\xd8V=\xa0' b'\xd5z(\x13`\xb09~\x17\xfdD\x91S\xebX\xa4'
# b'\xc4\xf6Tn\x99\xa0\xa3\x9f\xb9F\xbcr\xf9\x03\xf6}' b'\xa2\xdf\xa9B\x9b\xf2\xa0M\x8f#\xfe\x98\x02\t\xbdS'
# b'\xe5\x16#\x84\xb1\xbb\x85X:3\x85\x12\xca\xee\xbe\x9e' b'\xf1\x95\xc0 \xa2\x8d\xfc_/\xb6\xaf%kRM\xdc'
# b'J\x9e\x86\x85$0\xa0\x06\xfe\x97\x81Vy+\xa3`' b'\xc7\xda\x1f\xf9Z%\xc3S\xf11\x96\x04p>\x8b\xfd'
# b'\x8f\x00J\xde\xddL\x96\x7f\xeb\x8f3s\x07\xac\xf8@' b'\xebk\x0eqe\xa8\x11\x8bK\xd2\xde\x93\xfb\xe8\x18-'
# b'\xaf\xe3\xfe\xf2\xc5\x80\xf6\x02\x12\x9c| \x04V$\x12' b'\x10h\x7f\xeb\x97\x16\xc9P-\x9a@\xfd\xfe;\xb39'
# b'\xdf\x89\xac\xadt\xa1\xfb\xe0\xd7h\xe4\x0c6\x82a\xef' b'\x12\x1a\x9a\xf8\x89\xbdL\xa2&k\xe5\xa4\xf6\x80\xd3\xbe'
# b'\xad\xc5\x90\x98\xfe\x10\x89t\xba\xfc~\x81CC\x7f\xbf' b'\xf5\xef\xcd\x99O\xca\x89_dK\x0c\xcc6*\xba]'
# b'W\xa8\xbe\xf4\x0e\x17\xd7d\xba\xeb\xd7\xd6}\x9c\xfb\xa3' b'O\xb8\xcf\xea\xaa\xc8\n\x1c\x82\x9b"\xa40\x89\xefG'
# b'\xdd\xe1?\x9d\x9f\xd5R@(gB\xfa\x11\xd4\xe7\x1d' b'M\xf7\x13\x8b4\x15Y\xa9\x0f\xcf\x19\xaa\xc0\x99\xbf\xa6'
# b'dr\xeej\xb2\xb8?\xd9k\x99\xf6Y\xc3S\xb2>' b'\xdc\xf5\xbflc\xba\x8e2H?uf\x0b:j\x0f'
# b'l\\\x18\xca\xa2wg1P\xf4\x89B\x7f+\xaf]' b'\x99\xf2\xaa\x95\xe3o\x95\xc2\xac\xb0\xea\xf29\x98\xf00'
# b'7S[f\xcd!!\x9b\x18]\xc4y#\xc6\x08\x1a' b'\x19\xda\x91\xf2`8\x89&}\xfdwxn\x07\xa5\xb8'
# b'\xdf\xf8\x02K7+2|`$Y^W9U\xaa' b'RS\x8a\x80\tO{b\x94\x8f\xd3\x1eh\xfd\x17\xa3'
# b'9\xb8R\x05&>\xa3\x94\n\x13\xf5\xa71rnj' b'\xfe\x83\xf2\x17\xd4d\xf6\xfd\xfa[+\x1f\x87\xfe:\x1a'
# b'S\xc1\xc2\xe0@(\xca\xafAI\x93\xdf\x17}\xb9\x9b' b'9R|Y$z9\xd1\x8a\xd4\x8b\x99G\xeas\x83'
# b'\xb9\xc3t\x80\x8e\x1a\x07\xef\x8f\x8d\xbc\x85\n\xf7\xca.' b'$\x1c\xbdm\xfbnS\xc4<s\xb6/\x93\x845\x90'
# b'\xd4\x0e0:\x18\xf1"\x1e\xdc\x03v3]\x9d\x1bR' b'\xd8\xfc`\xcc\xdd\x8fU\\\x18X\xb9\xf0\x82\x0f&>'
# b'\xf3\xb6\xe7(\xe8\xf9\xd6\xa8\x03\xd3#\xac\x8b\x93\xb4\xc1' b'\xe2{\xd5\x10JYXDs\x0fD\xdfW\x1d\xe7\xda'
# b"\xf2\x9f\x8c\x0fs' \xdc2v\xc2E\x02\xa5\xee\xe3" b'\xf1\x1d\x1c\x80\xa3\xee\xec\x16\xed`y\xa5 \x05\xd4F'
# b'u:\xd1\x1bz;\xcdU\xeb\xcb\xec/2\xc1\x8a\x00' b'k\xac\xe8.\xa6@\xac\nx\x96<yH?\xaf\x0f'
# b'QG\xbd\xf31\xad\x15\xb8\xcdA\xe6!\xcb\xeft\x89' b'\xff\xc5L\xa8\x08\xe7fo%\x013\xad\n\xe2\x18Z'
# b'\x0f\x0b%`\x12)\xf9\x97\xbfR\x06?\x047\xab\x07' b'\xd5\x05\x91\xfft\\\xc80\x91\xf4\xee\x12\xb2\xeep,'
# b'\xa39\xab\xf4\x95Y\xbe\x1c\x05d\x15\x84W\xdeU\xf2' b'6\x1aR\x99fyD\\Eq\xc0\x14\xb2l\x881'
# b'\x04\x96\xff%.\x8f\x03l\xf3\x05\xe0\xbf\x91c\xaf\xee' b'w\xa5^\x8d\xd5oD(Iq\x16\xb9\x1dL\x0c;'
# b'\x7fi\x85n\x95\x9f\x03\xd4e\xb5\x8cd\x14\xdc\x8e\xa5' b'E\xa6Q\x93\xe3\x07\x84\xb0\x12OO\xede\x9e\xb7\xe4'
# b'H\xc3\xf5\x9a\xf6\x8d\x88`\x8a\xf5\xbeG\t\x00\xdf>' b'\xc0\x00\xa5\x13fam3\xf9\xdfa\xc9&\x0f\xbaE'
# b"\x00'\xc3{\xef\xde\xcc\x17%\xb1T{\x1c-\xad\xf9" b'\xe1D\xf0`\x8b\x1aC\xec\x8an\xa4\xedA\xf1\x98\xc9'
# b'Q\xb7\x88".<\x120\xb6\x1aG\xc3aH\xc4\xb6' b'\xf8@~\x18\x0b\xd9%\x89\xb7(\xaf!\xc5bl\x18'
# b'\x8d\xdb\xb1\xc5\x1d\xce\xf1\x93\xc38\xca6\x9f\xab\xe0\xb5' b'\x06\x1f\xb2\x08C\x1d\xb7\x93\xbb\xd3d[z\x16\x05\x8a'
# b"<\x9f\x9f\xe4'cskt\xdf\xcf\xdb\x0e6t\xa2" b'\x1a]*Ew,S\xd8\x03\xde\xf1\x07\xb6sf\xdb'
# b'I["\x19\xb5\xb4\xe1u^0n\xfd[\xf8W\xe7' b'\x08\xdb\xbfB\xca\xbae\x01\xb6\x9b\x1c\xeaz\x9b\x84\xe3'
# b'\xe0\x83\xa3F\xb2K\xca\xbb6SuW8:+\x93' b'\x904\xaa\xf4QC\x99j+\x14F\\5*\xb0\xc6'
# b"\x97\xea\xf9'=\xa1\xd2+_\xef%\x04\xcf\xde!\xf6" b'\xb7G\x1erM\xfb\xa2\x0bq&^\xb8\xf81_\xf5'
# b'\xb5\xee\xa6\xab\xb4\xc2S\xdaA\x0f\x1b\x84\x01N\x92\xcc' b'\xd3\xfe\x83\xb8\xd8|\xcd\xa2\xbb\xca^\x81\xce:\xb1\xa1'
# b'\xb8\xf2\xbb\xed>\xc9dR\x95p\xe20\xcf\xc5lf' b'!I\xaa\x9e\x07\xdd\xa9\xbb\xf5\x02\xe0\x88\xd8\xd0\xa3\x8e'
# b'\xf1\x03\x95D\x9d\x8cr\xc2\x9bp\x1a\xe4\x15\x15\x03\x87' b'\xcbF\xc7D\xc85A\xa0\x90\x0e\x1eax\x0c\x18\xd4'
# b'\x85YZ\xf2b5\xec\x00p\xa1lJ(v\x9b\x9c' b'\xe8\xeb\x9f\xaa]6l[\xd0Y\xb1\xba"\xc5\xfe\x8c'
# b'\xd5\xdf\xc5\xcf\xc0\x1a\xab\xba\xca|G\xacU\xf6\xf3\xe3' b'\x8b\xf7\xb4d\xaa\xa2\xc2\xb56\xaa\x1dv\xa1)|\x19'
# b'\x03\x1b,U7E\xad\xdc{}_G\x9f\xeb]\xb3' b'\xeb\xcd\xcb~\xff\xcc?\x06\xe0\xd5\x03c\x8a\xc6!\xde'
# b'W\xd4\xeczO{\x7f\x7fq\x07\xa1G\xd3\x10\xfbV' b'A\x05\xdbJ[\x81\xca\x1fWK/\r\x95v\xaa\xaf'
# b'\xaf\x15\xd3\xa1{\xac\x1f\xda\x87\xe2\xa3\xb3\x14\x7f\xd5x' b'\x8b2\x91\xa6 \x8f\xb6\x84\x9cd\x1e\x97\xff\xe5\xb5L'
# b'\x8e\xe1P\xe7ajO\xf43\x98>\xe2\xf9\x12\x18E' b'\x8c\xe2O\xc0\xea\x8eh^\xb2;\xf64g\x13\xad\x9f'
# b'Q\xb0\xcd\xc7\xbe\xc3\xd0."\x1c\xdeI\x82@\xfd\xc5' b"\x8c\x1ej\xb4'\x07\x92\xc5\x13\x04\xea\x06\xf4}\xc2\x0c"
# b'\x1a\tf\xb54\x92\xcc6\x82.\x91\x03\xb8\x04\xc7\xe0' b'\x96I\x92\xfd\xe3\x029\xaf&6e^X\xd7\x14\xe7'
# b'arbitrarymessage' b'~\xf8\xaaj3kJq"\x03\x1dq?8?\xfb'
# b'!\x1e\x06\x02\xcer\xe4\xfa\xefq\xb6\xfb\xf0\x0f\x18\x08' b'\x12\xbd\xd0\x0f\xd4\x03\x87V\xcb\xcf\x8e\xcd\xad\x1b\x0c\xd8'
# b'\x15\x07i\xb9O\xad\x1b|\x84\xa74T\xef\xa4\x13(' b'\xa6\xf5t%\x13~\x9a\xa5E7\xf0\xb3\xf56L\xe1'
# b'#\xae\xd1\x7f\x83\x9d\xdb\xf4v=\xfc\xb66\x1b\xeei' b'\x12o\xe4\r\x9ed\xdf"<\x05\x07\x8fD\xbfW\xcb'
# b'T\xff\x94\xdcF\x87NG3\xc9\xdb\xbc\xe2\x12\xf3\xc2' b'\x82\xbb>\xab\x86\xd4\x06>\xa4\xa3\xcb\x97\x82\x1f\xeb\x07'
# b'a\x06W1\xec\xb2Mw\xed)\xf2/MJ\xbbz' b'\x1am\xba\xa7\x17\xf8\x83|K\xd43!!\xe9+\xd7'
# b'&\x8fJ\xac\xcb@ld\x96 \xd1\xdd\x12\x02mS' b'e_+q\xdd\xfa\xfb\xcb\xd5\xafQ\x7f\x02\xeb\x93\x86'
# b'9\xf8=@O(\xc1\x03\xf2r10\x1ct\xc5\xbe' b'\xc3\x14\xf8\xc1\xfa\x13\xe1\xaf\xa1\x1c\x87\x16\xc7\xbc\xe6\xdb'
# b'\xb7\xfb0\xff0\xe9H\xe1\n\x05\nalt\xba\xc0' b'\xf8\x99\x8d\xa8_\xb1-N\x8a\x85\x8d6J\xb4\x85\xdf'
# b'\xd2\xe37b\xcdL\xb9\t\x8d\x9df=\x86\xda\x9cI' b'\xb3M\xb2\xb7-c\xf3=\xbe\xf8\x0f\xb3\x0e\tL\xc0'
# b'\xaa7duz\x04\xc8KU\xe4\xa6\x12b\x82\x9a\xaa' b'\xc1Q\xb7`imfRe\x18u\x01\xc5\x1f8\xcd'
# b"\x16\xa7>\x9c\x0e(L\xab\xa7\xd3'0x\xbfcD" b'\x18\x9e\xbf\x93\xbe9f\xe5>P\x8diB&\xaf\x88'
# b'4\xb6\\\xa5\xc7N}s\xb1\x9bS"\xa0A\x138' b'j/\xfa5g\xb0\xd2\x864\x8fNiB\xd3\xe8\xe6'
# b'\xa1\xbd\xaf\x04\xb5\x1b"\xaeL\xd1\xbd\xb11\xae\x0c>' b'\xb3\xe0\x16t\xa1\xe4\xddx\xe7Hx/\xcf\xc3\xad\xd5'
# b'\xac+\xd6P\xe5\t\xdb\x87O\xce\xd8f\x86\xd4\xf6t' b'\x1d\xcf\x0e\xc25\x19f\xfc+\x0b\xab\xeex\x7fSZ'
# b'n`o>l\x02\xabf\x93\xbd\x04 ,\xe5\xdb\xda' b'\xec}\x07\x01t\xe4\n\xceg\x80\x06\xd0\xc61\x02o'
# b'\xd4,\xf3\x8c\xed\x99\x05\xa9o\xb9\x00\x12<N}3' b'\xae\xbfd\x9aQ\x82g\xa3\x9a\xbe`\xe3\xef\xbc\x135'
# b'\xd4\xa9T\x92\xb46\xa8\xa6\x02&{T\x01\x04/2' b'\x12\x16\xaaRJ\xefu\xe7Z\xa9!O\xb7\x8a\xd1\xac'
# b'\n\xc0\x01\x0b\xe4\x86]\xac\x8c\xc7\xc6\xebf\x1a8\x0c' b'_\xb9\xa0\xba7Q\x9b\x7f\xd5\x19\t\xc7x\xee;H'
# b'\xfc\xa2\x7f\xb4\x81\x11o\x8a\xb3\xcb\xbd\xf9A0\x8a\xac' b'\xa4\xac@\x8f\xb9\xd6\xde\xf0p\xad:v1,\xa0\x92'
# b'\x0e\x84\x065\xa4\xc6\x1eEG\x17u"\x93V\x8e\xfc' b'\xa3\xb607\xf3\xb6\xd7O\xc4\xe7\x15o\\\xdc\xbd\x90'
# b'x\xaa\xadB\xa2A\xf3\xa1\x94\xb9\xb0\xc4\x9a\x88\x87\xc7' b'?\xa5\xbf\xd93\x17\xad%w&\x80\x07\x1dZ\xc3%'
# b'\x08\xaeD\xa0\\z\x18\xe0?\xa5\xd7\xc5k\x1azg' b'\xc2 N\xdb\xfb\x1br\xc9\xe9\x96\xa5\xe6FOj\xb0'
# b':\x8e6\xe6\xb1\xb5)jE\xf4\xc7\xdf\x89O\x03\xb0' b'\xb7S\xd66\xf6\xeeF\xbb\x92B\xd0\x1f\xf8\xb6\x1fq'
# b')\xdexP\xeb\xa0\x9b>X\xab\xe0I\xc1\xe2\x10\x1f' b'\xddy\xc8\xcf\xb8\xbe\xea\xcd\x04`B\x99D\xb4\xec\xbe'
# b'.\x12\x05o8\xd3\x16\xc7\xc8\xec\xbd9\x9b\xc7L\x85' b'\xad\xad,\xa7\xab1:\xddn\x95_pG\x19\xe0='
# b'\xc6\n.\x9dV\xaa\x9f\xa5N\x8b\xb7\xda\xc8\xd1\x91\xb2' b'~\\\x0fz\xba2\xcf>"\xfd0\xc4Q:!\xe6'
# b'\x90\xc2\xd8\xe3)\x10\x8f\xff^Y\\\xc8\x81\xca8\x87' b'\x80\xb6V\x90\xc5\xa9\xbfw\x97\xa8\xcc\xc6\xc3P\xca\xd4'
# b'\xd2bf\xee\x15\xf8\x0e\xa5F\x189\xebwz\x9dn' b'\x12\xdb\x8f\x85\xbf\xe3\xe0\xb87\x05\x9f\xa0\x1eSt\x8a'
# b'\xef\xfeh\xe9\x80\x97\x02\x17l\xc4c!\xad\x89\xeev' b'\x13,\xcf\x0b\xbe\xff\xceJ\xf8\xe8\x8c\x1c8\xcbg\xd3'
# b"\x981\xd98\x9a^j\x0bY\x8e\xcb\xafT'\xc1\xea" b'v\x8a\xab7\xc2\x92\x01\x013\x97\x9e\x82\x1a\xd5\xac\x08'
# b'K\x0b`e\xf3\x10\xf9\xc1\xcf\xd8\xf8\xa4\xecz\x8c;' b'\x15\x99\xe9\xfaA\xech\xc8\x020I\x19\x02xk\xee'
# b'\xff{\x94\x91\xbd\xb9\xc7\x81\x1b\xcb\x9a.A\xaf*\x1b' b'<\x89Xm\x99\xf2V}!A\x0f)\xb1\xb2`e'
# b'\xea7\x1dup&S\xaa\xb3O* \xf8\xc5e6' b'\xa7\x0f\xb6\xa9A]<4\xa9\xeaU\x10\xba~:\x05'
# b'\x85\x95\x90\xac\xdbQ8V\xba\xfc\xc75S\xcd\xcf\x1a' b'\n\xd0R\xdd\x9f2@U!\xe4<n\xbd\xc5/Z'
# b"\x1c\xfd1\x81\x10ai\xcd\x89>\xf9'\x0fH\xf6\xcd" b'\x1d\xc3\x88-K\xcc\xcb2WQ\x80;\x81t\x89\xc3'
# b'\xbb\xfc\xfd\xa6PK}\x8a\x04\xa1O\x9b{9\xcc\x08' b'w\xac4\x1f\xee\xbe\xb7\xc0\xa7\xff\x8f\x9ce@S\x15'
# b'dw\x13\xf5@\xce\x83.,\xe8\xcc\x1c\x15\x83\xc7\x03' b'U\xdf*Y\xedj\x88\x8e\xe2\xf0\xcd\xfd\xcc\x85\x82i'
# b'\xdf\xb6\xbdv\xb0\xb3\xbd\x8a\x1a{\xbe\xe1Ao\xd5N' b'\xef\xe4=\xef\x97\xeb)_\xe9\x9c7S\xf2\xd7@\xd7'
# b'\x10\x10|\x83\xbf\xfe\x89q\x02\xf0\x94\xb5\xc7\x97J\xcd' b'\x07\xb7%^\xac\xbc\x81\xc0QD^\xbeO\x8ct\xfc'
# b'\x0c\x13n\xd1\xf8\x96\xd9VP\x12\xa0\xaf\xe7\xb7\xab\x17' b'\x98k!$ \xe3\xb9w\x06\x82D\xe6\xbd\x91eu'
# b'\x936\x17\xc1\x03\xb9\rVJCJ\xbb\xd8b\xe6\xa3' b'\n\x80\xba\xa1yv\x15\xfa\xdd\xb0\xcc\xfa\xa6\xd4c\x82'
# b'\x1cZ\x96\xf4\xa8s<\xe5\\\xce\x06\x0c\xaf8\x80o' b'\xb4\x8fI\x17\x83\xe9\x8d\xe1\x06\x82\xf2\xd4E]\xfc\xe5'
# b'^\xb9=\xa8\xb2e\xf3\x93@"\xaf\xb5\x83j\xe0\xc3' b'\xc6k\xe7!\t\x15\xf3\x9e\x91Eo\xc2\xea\xc9D\x10'
# b'\n[\xaar\x9bDz\x15-\xfaRJ\x1d\x07\x14\x11' b'\x9b\x16f\x8fN\x16\xc0\xe9\x93&a\x85[{\xcb['
# b'\x82\xcc\x1f\xe4;\xee7\x18\x19E\xfbf.\xb9_\xf0' b's\xb7G6fJ\xd8X(\xce\x1b\xe2\xe2\x9f\xb4\xa6'
# b'\x19\xd0\xc8[MWzK\x83G\x1f;\x91\x1dO\xcd' b't[\xed\xb7\x94\x13\xd2\x08D\xa8\xb0\xe9o\xbe\xc5\x1b'
# b'\xdc\xcel\xc1\x04\xae\x08{~\xeb\xdeU]\xe0#9' b'\xa1\xa7q\\u\x96\xc7{\x89-\xc6\xd4\xde\xbb|\x10'
# b'\xcb\x16P\xb1:L/\xba\x07\x1by\x8d\xd6P\xca\xf5' b':\xce\xad\x9c\x86\xf21\xec\x12\x81\x94\xb5\r\xefz\x93'
# b'\xea=OX,%\x9f\x05\xdf\xad\x98p\xa7\xb7\x81\xb8' b'\xd0~K\xc7\x86\xc8\x8b\x8d#\x04\xf8L}\xb2\t\x86'
# b'\xcb\xcc\x16)\x92c\xde-\x85\x1dh.S[=\xac' b'\xabF\x1fk\x8ahB\xa4s%z%a\xc1\xfb\xdf'
# b"\xff]H\x02~c.>#\x15\xf6\xe8]q'\x03" b'\xb5Fd\x96Y\x11\xc6\xfe\x91\xe1\x8c\xd0\x1bh\xa7\\'
# b'\x00\xda(\x9as\xa2\xa28\x80:\x1f[\x19]EB' b'\xb6\x85B7<\x05\xc0\xed%#\x1d\t\x95[,i'
# b'c\xccB1G2\x01.\xbb\x1es\x8e,\xbb\xb9u' b'\x85\xe52q\xe1@\x06\xf0&Y!\xd0-Msl'

# %% [markdown]
# # TRNG

# %% [markdown]
# # Sources: dev/random, dev/urandom
# These two files provide secure way to generate random bytes!
# Reading from dev/urandom can by done using following functions:

# %%
import os
import secrets 
os.urandom(10)
print(secrets.token_bytes(10).hex())
print(os.getrandom(10).hex())
# Out:
# b'^\xc3\x16\xf3\xe1\xf5\r\xee\xff,'
# b"Lrmg\xa8x'\x05\xc7j"

# %% [markdown]
# Files **dev/random**, **dev/urandom** can be also opened as binary file for reading.
# Then you can read specified number of bytes e.g. 10.

# %%
random_source = open("/dev/random", "rb")
random_source.read(10)
# Out:
# b'b\xd0\xbd\xb4\xe2\xd1\xae`cL'

# %% [markdown]
# # Task 5: Testing correlation of bits
#  1. Implement function `histogram(rnd_bytes, i, j)` that computes histogram of combination of bits (`i`-th and `j`-th bits of each byte). The function should return 4 frequencies for all bytes in `rnd_bytes` array. Frequencies will correspond to counts of how many bytes have `i`-th and `j`-th bit equal to combination 00,01,10 or 11.

# %%
import os
def histogram(rnd_bytes, i, j):
    hist = {0:0, (1 << i):0, (1 << j):0, (1 << i) + (1 << j): 0}
    mask = (1 << i) + (1 << j)
    for byte in rnd_bytes:
        hist[byte & mask] += 1
    return hist

# %% [markdown]
#  2. Verify that for arbitrary params `i,j` and size of generated block the frequencies are roughly equal.

# %%
rnd_bytes = os.urandom(1000)
histogram(rnd_bytes, 0, 1)
# Out:
# {0: 270, 1: 234, 2: 247, 3: 249}

# %% [markdown]
#  3. Generate random bytes using ansi_rand = generate integers, apply modulo, transform to bytes (use `bytes()`).
#  4. Find params `i,j` where all the frequencies are exacly the same.
#  <span style="color:red"> Generator with such perfect results is also problematic! </span>
#  Can we predict some (next) bits with better probability than 50% ?

# %%
ansi_rand.srand(6)
rnd_bytes = bytes([ansi_rand.rand() % 256 for i in range (1000)])
histogram(rnd_bytes, 0, 1)
# Out:
# {0: 250, 1: 250, 2: 250, 3: 250}
